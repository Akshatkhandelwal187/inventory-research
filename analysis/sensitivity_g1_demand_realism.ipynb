# %% [markdown]
# # Sensitivity analysis — gap G1: demand realism in carbon-aware models
#
# Vary the power-demand exponent `n` (Sicilia 2014) under each carbon regime and observe how Q*, T*, total cost, and emissions move. Stub for Phase 5.
