# %% [markdown]
# # Sensitivity analysis — gap G4: regulatory comparison under non-stationary demand
#
# Compare tax, cap-and-trade, and strict-cap regimes under power demand using `src/novel/stage_3c_multipolicy.py`. Stub for Phase 5.
