# %% [markdown]
# # Sensitivity analysis — gap G2: emissions cost of backlogged shortages
#
# Vary `e_s` (emissions per backlogged unit per unit time) and observe whether ignoring backlog emissions biases the optimal policy. Stub for Phase 5.
