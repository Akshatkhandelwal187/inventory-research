# %% [markdown]
# # Sensitivity G6 — deteriorating items at the intersection (DEFERRED)
#
# G6 is **out of scope for Phase 5**. None of the five reference papers carries a deterioration term, so closing this gap requires a model extension rather than a parameter sweep over the existing solver.
#
# The cell below renders the full deferral memo at `analysis/sensitivity_g6_deferred.md`, which records the rationale and the work needed to lift it.
#
# There is no CSV or figure for G6.

# %%
import os, sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "analysis":
    ROOT = ROOT.parent
    os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from IPython.display import Markdown
Markdown(Path("analysis/sensitivity_g6_deferred.md").read_text(encoding="utf-8"))
